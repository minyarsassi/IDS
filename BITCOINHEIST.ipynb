# %% [markdown]
# <a href="https://colab.research.google.com/github/minyarsassi/IDS/blob/master/BITCOINHEIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #load and summarize the dataset
import pandas as pd
#load the dataset 
BH=pd.read_csv('BitcoinHeistData.csv',delimiter=',')
#summarize the dataset ²²
print(BH.describe())
nRow,nCol=BH.shape
print(f'there are {nRow} rows and {nCol} Colums')
BH.head(10)
# Out:
#                 year            day  ...      neighbors        income
# count  522774.000000  522774.000000  ...  522774.000000  5.227740e+05
# mean     2011.548290     156.628834  ...       1.817761  1.037727e+10
# std         1.130496     104.918472  ...      10.225059  3.502630e+11
# min      2011.000000       1.000000  ...       1.000000  3.000000e+07
# 25%      2011.000000      68.000000  ...       1.000000  1.116718e+08
# 50%      2011.000000     129.000000  ...       2.000000  5.670581e+08
# 75%      2012.000000     246.000000  ...       2.000000  3.429212e+09
# max      2018.000000     365.000000  ...    1770.000000  4.996440e+13
#
# [8 rows x 8 columns]
# there are 522775 rows and 10 Colums
#                               address    year  ...       income            label
# 0   111K8kZAEnJg245r2cM6y9zgJGHZtJPy6  2017.0  ...  100050000.0  princetonCerber
# 1  1123pJv8jzeFQaCV4w644pzQJzVWay2zcA  2016.0  ...  100000000.0   princetonLocky
# 2  112536im7hy6wtKbpH1qYDWtTyMRAcA2p7  2016.0  ...  200000000.0  princetonCerber
# 3  1126eDRw2wqSkWosjTCre8cjjQW8sSeWH7  2016.0  ...   71200000.0  princetonCerber
# 4  1129TSjKtx65E35GiUo4AYVeyo48twbrGX  2016.0  ...  200000000.0   princetonLocky
# 5  112AmFATxzhuSpvtz1hfpa3Zrw3BG276pc  2016.0  ...   50000000.0   princetonLocky
# 6  112E91jxS2qrQY1z78LPWUWrLVFGqbYPQ1  2016.0  ...  100000000.0  princetonCerber
# 7  112eFykaD53KEkKeYW9KW8eWebZYSbt2f5  2016.0  ...  100990000.0  princetonCerber
# 8  112FTiRdJjMrNgEtd4fvdoq3TC33Ah5Dep  2016.0  ...   80000000.0  princetonCerber
# 9  112GocBgFSnaote6krx828qaockFraD8mp  2016.0  ...   50000000.0   princetonLocky
#
# [10 rows x 10 columns]

# %%
for i in range(len(BH.index)) :
    print(" Total NaN in row", i + 1, ":",
          BH.iloc[i].isnull().sum())
# Out:
#  0
#  Total NaN in row 68179 : 0
#  Total NaN in row 68180 : 0
#  Total NaN in row 68181 : 0
#  Total NaN in row 68182 : 0
#  Total NaN in row 68183 : 0
#  Total NaN in row 68184 : 0
#  Total NaN in row 68185 : 0
#  Total NaN in row 68186 : 0
#  Total NaN in row 68187 : 0
#  Total NaN in row 68188 : 0
#  Total NaN in row 68189 : 0
#  Total NaN in row 68190 : 0
#  Total NaN in row 68191 : 0
#  Total NaN in row 68192 : 0
#  Total NaN in row 68193 : 0
#  Total NaN in row 68194 : 0
#  Total NaN in row 68195 : 0
#  Total NaN in row 68196 : 0
#  Total NaN in row 68197 : 0
#  Total NaN in row 68198 : 0
#  Total NaN in row 68199 : 0
#  Total NaN in row 68200 : 0
#  Total NaN in row 68201 : 0
#  Total NaN in row 69821 : 0
#  Total NaN in row 69822 : 0
#  Total NaN in row 69823 : 0
#  Total NaN in row 69824 : 0
#  Total NaN in row 69825 : 0
#  Total NaN in row 69826 : 0
#  Total NaN in row 69827 : 0
#  Total NaN in row 69828 : 0
#  Total NaN in row 69829 : 0
#  Total NaN in row 69830 : 0
#  Total NaN in row 69831 : 0
#  Total NaN in row 69832 : 0
#  Total NaN in row 69833 : 0
#  Total NaN in row 69834 : 0
#  Total NaN in row 69835 : 0
#  Total NaN in row 69836 : 0
#  Total NaN in row 69837 : 0
#  Total NaN in row 69838 : 0
#  Total NaN in row 69839 : 0
#  Total NaN in row 69840 : 0
#  Total NaN in row 69841 : 0
#  Total NaN in row 69842 : 0
#  Total NaN in row 69843 : 0
#  Total NaN in row 69844 : 0
#  Total NaN in row 69845 : 0
#  Total NaN in row 69846 : 0
#  Total NaN in row 69847 : 0
#  Total NaN in row 69848 : 0
#  Total NaN in row 69849 : 0
#  Total NaN in row 69850 : 0
#  Total NaN in row 69851 : 0
#  Total NaN in row 69852 : 0
#  Total NaN in row 69853 : 0
#  Total NaN in row 69854 : 0
#  Total NaN in row 69855 : 0
#  Total NaN in row 69856 : 0
#  Total NaN in row 69857 : 0
#  Total NaN in row 69858 : 0
#  Total NaN in row 69859 : 0
#  Total NaN in row 69860 : 0
#  Total NaN in row 69861 : 0
#  Total NaN in row 69862 : 0
#  Total NaN in row 69863 : 0
#  Total NaN in row 69864 : 0
#  Total NaN in row 69865 : 0
#  Total NaN in row 69866 : 0
#  Total NaN in row 69867 : 0
#  Total NaN in row 69868 : 0
#  Total NaN in row 69869 : 0
#  Total NaN in row 69870 : 0
#  Total NaN in row 69871 : 0
#  Total NaN in row 69872 : 0
#  Total NaN in row 69873 : 0
#  Total NaN in row 69874 : 0
#  Total NaN in row 69875 : 0
#  Total NaN in row 69876 : 0
#  Total NaN in row
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-964dd439a92d> in <module>()
#       1 for i in range(len(BH.index)) :
#       2     print(" Total NaN in row", i + 1, ":",
# ----> 3           BH.iloc[i].isnull().sum())
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     503                 )
#     504             data.group = group
# --> 505         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     506
#     507     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
BH.drop(columns=["address","year","day"])
# Out:
#         length        weight  count  ...  neighbors        income            label
# 0         18.0  8.333333e-03    1.0  ...        2.0  1.000500e+08  princetonCerber
# 1         44.0  2.441406e-04    1.0  ...        1.0  1.000000e+08   princetonLocky
# 2          0.0  1.000000e+00    1.0  ...        2.0  2.000000e+08  princetonCerber
# 3         72.0  3.906250e-03    1.0  ...        2.0  7.120000e+07  princetonCerber
# 4        144.0  7.284841e-02  456.0  ...        1.0  2.000000e+08   princetonLocky
# ...        ...           ...    ...  ...        ...           ...              ...
# 522770     8.0  4.699638e-02   21.0  ...        1.0  2.369081e+08            white
# 522771     4.0  1.000000e+00    1.0  ...        2.0  1.150000e+08            white
# 522772     0.0  5.000000e-01    1.0  ...        1.0  5.035000e+09            white
# 522773   144.0  5.031520e-12  276.0  ...        2.0  6.460465e+08            white
# 522774     NaN           NaN    NaN  ...        NaN           NaN              NaN
#
# [522775 rows x 7 columns]

# %%
#Categorical data (binar)
BH["mlabel"]="ransomware"
BH["mlabel"][BH["label"]=="white"]="legitime"
gb=BH.groupby("mlabel")
gb.count()

#dropping label
BH=BH.drop(columns=["label","address","year","day"])
gb=BH.groupby("mlabel")
gb.count()
BH.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    length        weight   count  looped  neighbors       income      mlabel
# 0    18.0  8.333333e-03     1.0     0.0        2.0  100050000.0  ransomware
# 1    44.0  2.441406e-04     1.0     0.0        1.0  100000000.0  ransomware
# 2     0.0  1.000000e+00     1.0     0.0        2.0  200000000.0  ransomware
# 3    72.0  3.906250e-03     1.0     0.0        2.0   71200000.0  ransomware
# 4   144.0  7.284841e-02   456.0     0.0        1.0  200000000.0  ransomware
# 5   144.0  8.461400e-02  2821.0     0.0        1.0   50000000.0  ransomware
# 6   142.0  2.088519e-03   881.0     0.0        2.0  100000000.0  ransomware
# 7    78.0  3.906250e-03     1.0     0.0        2.0  100990000.0  ransomware
# 8   144.0  2.302828e+00  4220.0     0.0        2.0   80000000.0  ransomware
# 9   112.0  3.725290e-09     1.0     0.0        1.0   50000000.0  ransomware

# %%
#getting all ransomware
heist_df1=BH.loc[BH['mlabel']=="ransomware"]
#getting all légitime
heist_df2=BH.loc[BH['mlabel']=="legitime"]
#randomly select 158587 instance
heist_df2=heist_df2.sample(n=158587,replace=True)
heist_df=heist_df1.append(heist_df2)
#mixing the order of columns such that the légitime and ransomware are randomly distributed
heist_df=heist_df.sample(n=200000,replace=True)
#reindex the dataframe
heist_df.reset_index(drop=True,inplace=True)
print(heist_df.shape)
heist_df.head(10)
# Out:
# (200000, 7)
#    length    weight  count  looped  neighbors        income    mlabel
# 0     0.0  1.000000    1.0     0.0        2.0  3.000000e+08  legitime
# 1     0.0  0.500000    1.0     0.0        2.0  7.100000e+07  legitime
# 2    66.0  0.000244    1.0     0.0        2.0  4.916173e+08  legitime
# 3    46.0  0.000004   36.0     0.0        2.0  1.665599e+09  legitime
# 4    22.0  0.003906    1.0     0.0        1.0  6.500000e+07  legitime
# 5    26.0  0.000122    1.0     0.0        2.0  8.289913e+08  legitime
# 6     0.0  1.000000    1.0     0.0        2.0  1.872760e+08  legitime
# 7    20.0  0.015625   36.0     0.0        2.0  3.877250e+09  legitime
# 8     0.0  1.000000    1.0     0.0        1.0  6.000000e+10  legitime
# 9     2.0  0.500000    1.0     0.0        2.0  8.951093e+08  legitime

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
heist_df=heist_df.drop(columns=["mlabel"])
scaled_data=scaler.fit_transform(heist_df)
scaled_data
# Out:
# array([[-0.63024772,  0.27954616, -0.19504479, -0.08631716,  0.00874159,
#         -0.02519855],
#        [-0.63024772,  0.02765315, -0.19504479, -0.08631716,  0.00874159,
#         -0.02577099],
#        [ 1.08582002, -0.22411687, -0.19504479, -0.08631716,  0.00874159,
#         -0.02471955],
#        ...,
#        [-0.26623335, -0.11657376, -0.094358  , -0.08631716, -0.07071654,
#         -0.00551027],
#        [-0.57824567, -0.17773654, -0.1777842 , -0.08631716, -0.07071654,
#         -0.02569505],
#        [-0.63024772,  0.27954616, -0.19504479, -0.08631716, -0.07071654,
#         -0.02494857]])

# %%
#imorting sampler
from imblearn.under_sampling import RandomUnderSampler
# define undersample strategy
undersample = RandomUnderSampler(sampling_strategy='majority')
y=BH.mlabel
BH=BH.drop(columns="mlabel")
#fitting the sampler
X_over, y_over = undersample.fit_resample(BH, y)
#transforming X_over et y_over to pandas dataframe
xx=pd.DataFrame(X_over)
yy=pd.DataFrame(y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-ce351bc15ce9> in <module>()
#       6 BH=BH.drop(columns="mlabel")
#       7 #fitting the sampler
# ----> 8 X_over, y_over = undersample.fit_resample(BH, y)
#       9 #transforming X_over et y_over to pandas dataframe
#      10 xx=pd.DataFrame(X_over)
#
# /usr/local/lib/python3.7/dist-packages/imblearn/base.py in fit_resample(self, X, y)
#      78         self._deprecate_ratio()
#      79
# ---> 80         X, y, binarize_y = self._check_X_y(X, y)
#      81
#      82         self.sampling_strategy_ = check_sampling_strategy(
#
# /usr/local/lib/python3.7/dist-packages/imblearn/under_sampling/_prototype_selection/_random_under_sampler.py in _check_X_y(X, y)
#     101     def _check_X_y(X, y):
#     102         y, binarize_y = check_target_type(y, indicate_one_vs_all=True)
# --> 103         X = check_array(X, accept_sparse=['csr', 'csc'], dtype=None)
#     104         y = check_array(y, accept_sparse=['csr', 'csc'], dtype=None,
#     105                         ensure_2d=False)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     576         if force_all_finite:
#     577             _assert_all_finite(array,
# --> 578                                allow_nan=force_all_finite == 'allow-nan')
#     579
#     580     if ensure_min_samples > 0:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      58                     msg_err.format
#      59                     (type_err,
# ---> 60                      msg_dtype if msg_dtype is not None else X.dtype)
#      61             )
#      62     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
print(xx.shape)

# %%
#importing libraries
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder() 
#fitting transformation
heist_df['mlabel']= label_encoder.fit_transform(heist_df['mlabel']) 

print(heist_df.shape)
heist_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mlabel'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-3e629d7cd068> in <module>()
#       3 label_encoder = preprocessing.LabelEncoder()
#       4 #fitting transformation
# ----> 5 heist_df['mlabel']= label_encoder.fit_transform(heist_df['mlabel'])
#       6
#       7 print(heist_df.shape)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'mlabel'

# %%
#importing library from sklearn
from sklearn.ensemble import IsolationForest
#creating the model
model=IsolationForest(n_estimators=50, max_samples='auto',
contamination=float(0.1),max_features=1.0)
model.fit(heist_df[['looped']])
# Out:
# IsolationForest(behaviour='deprecated', bootstrap=False, contamination=0.1,
#                 max_features=1.0, max_samples='auto', n_estimators=50,
#                 n_jobs=None, random_state=None, verbose=0, warm_start=False)

# %%
heist_df['scores']=model.decision_function(heist_df[['looped']])
heist_df['anomaly']=model.predict(heist_df[['looped']])
heist_df.head(20)
# Out:
#     length    weight   count  looped  neighbors        income  scores  anomaly
# 0      0.0  1.000000     1.0     0.0        2.0  3.000000e+08     0.0        1
# 1      0.0  0.500000     1.0     0.0        2.0  7.100000e+07     0.0        1
# 2     66.0  0.000244     1.0     0.0        2.0  4.916173e+08     0.0        1
# 3     46.0  0.000004    36.0     0.0        2.0  1.665599e+09     0.0        1
# 4     22.0  0.003906     1.0     0.0        1.0  6.500000e+07     0.0        1
# 5     26.0  0.000122     1.0     0.0        2.0  8.289913e+08     0.0        1
# 6      0.0  1.000000     1.0     0.0        2.0  1.872760e+08     0.0        1
# 7     20.0  0.015625    36.0     0.0        2.0  3.877250e+09     0.0        1
# 8      0.0  1.000000     1.0     0.0        1.0  6.000000e+10     0.0        1
# 9      2.0  0.500000     1.0     0.0        2.0  8.951093e+08     0.0        1
# 10    10.0  0.031250     1.0     0.0        1.0  2.030000e+08     0.0        1
# 11     0.0  1.000000     1.0     0.0        1.0  1.000000e+08     0.0        1
# 12    20.0  0.000977     1.0     0.0        2.0  2.585477e+09     0.0        1
# 13     2.0  0.500000     1.0     0.0        1.0  5.002000e+07     0.0        1
# 14   144.0  0.031752  2723.0     0.0        1.0  1.000000e+08     0.0        1
# 15     0.0  1.000000     1.0     0.0        2.0  9.000000e+07     0.0        1
# 16     0.0  0.500000     1.0     0.0        2.0  2.990000e+09     0.0        1
# 17    36.0  0.000507    54.0     0.0        2.0  2.944150e+09     0.0        1
# 18     0.0  0.500000     1.0     0.0        2.0  1.437750e+10     0.0        1
# 19     8.0  0.500000     1.0     0.0        2.0  2.440988e+09     0.0        1

# %%
anomaly=heist_df.loc[heist_df['anomaly']==-1]
anomaly_index=list(anomaly.index)
print(anomaly)
# Out:
#         length    weight   count  ...        income    scores  anomaly
# 31        76.0  0.032452    27.0  ...  5.123000e+09 -0.339448       -1
# 48        10.0  1.750000     3.0  ...  4.000000e+08 -0.194985       -1
# 58       144.0  0.010328  1799.0  ...  8.902086e+07 -0.498518       -1
# 59        24.0  0.000732     2.0  ...  3.997000e+09 -0.247808       -1
# 67        30.0  3.115948    41.0  ...  5.000000e+09 -0.194985       -1
# ...        ...       ...     ...  ...           ...       ...      ...
# 199932   144.0  2.528705  1336.0  ...  9.298817e+08 -0.349598       -1
# 199938   144.0  0.594137  1629.0  ...  3.799900e+08 -0.309581       -1
# 199965     6.0  0.013145    22.0  ...  5.480027e+07 -0.339587       -1
# 199967     4.0  0.035750    17.0  ...  5.148230e+08 -0.343332       -1
# 199993   144.0  0.781407  2502.0  ...  7.986063e+07 -0.247808       -1
#
# [14260 rows x 8 columns]

# %%
import matplotlib.pyplot as plt

fig, axes= plt.subplots(2, 3, figsize=(16, 5))
ax1,ax2,ax3,ax4,ax5,ax6= axes.flatten()
ax1.hist(heist_df['length'], bins=100)
ax1.set_title("length distribution")
ax2.hist(heist_df['weight'], bins=100)
ax2.set_title("weight distribution")
ax3.hist(heist_df['count1'], bins=100)
ax3.set_title("count distribution")
ax4.hist(heist_df['looped'], bins=100)
ax4.set_title("looped distribution")
ax5.hist(heist_df['neighbors'], bins=100)
ax5.set_title("neighboors distribution")
ax6.hist(heist_df['income'], bins=100)
ax6.set_title("income distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'count1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-2321d98b8ba2> in <module>()
#       8 ax2.hist(heist_df['weight'], bins=100)
#       9 ax2.set_title("weight distribution")
# ---> 10 ax3.hist(heist_df['count1'], bins=100)
#      11 ax3.set_title("count distribution")
#      12 ax4.hist(heist_df['looped'], bins=100)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'count1'

# %%
import matplotlib.pyplot as plt
plt.hist(heist_df.income, bins=20, rwidth=0.8)
plt.ylabel('income')
# Out:
# Text(0, 0.5, 'income')

# %%
plt.hist(heist_df.neighbors, bins=20, rwidth=0.8)
plt.ylabel('neighbours')

# %%
plt.hist(heist_df.length, bins=20, rwidth=0.8)
plt.ylabel('length')

# %%
plt.hist(heist_df.weight, bins=20, rwidth=0.8)
plt.ylabel('weight')

# %%
plt.hist(heist_df.looped, bins=20, rwidth=0.8)
plt.ylabel('looped')

# %%
heist_df=heist_df.rename(columns={"count": "count1"})

# %%
plt.hist(heist_df.count1, bins=20, rwidth=0.8)
plt.ylabel('count1')

# %%
# Correlation matrix
def plotCorrelationMatrix(df, graphWidth):
    
    
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='k')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title(f'Correlation Matrix for df', fontsize=15)
    plt.show()

# %%
import matplotlib.pyplot as plt
plotCorrelationMatrix(heist_df,8)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-2d6f08759ff2> in <module>()
#       2 from sklearn.preprocessing import StandardScaler
#       3 sc = StandardScaler()
# ----> 4 X_train = sc.fit_transform(X_train)
#       5 X_test = sc.transform(X_test)
#
# NameError: name 'X_train' is not defined

# %%
import numpy as np
def detect_outliers(data):
    outliers=[]
    threshold=3
    mean = np.mean(data)
    std =np.std(data)
    
    for i in data:
        z_score= (i - mean)/std 
        if np.abs(z_score) > threshold:
            outliers.append(i)
    return outliers

# %%
outliers=detect_outliers(heist_df["income"])
print(len(outliers))

# %%
heist_df['zscore'] = ( heist_df.income- heist_df.income.mean() ) / heist_df.income.std()
h=heist_df[(heist_df.zscore>-3) & (heist_df.zscore<3)]
print(h.shape)
h.head()

# %%
h['zscore'] = ( h.weight- h.weight.mean() ) / h.weight.std()
h2=h[(h.zscore>-3) & (h.zscore<3)]
print(h2.shape)
h2.head()

# %%
h2['zscore'] = ( h2.neighbors- h2.neighbors.mean() ) / h2.neighbors.std()
h3=h2[(h2.zscore>-3) & (h2.zscore<3)]
print(h3.shape)
h3.head()

# %%
h3['zscore'] = ( h3.length- h3.length.mean() ) / h3.length.std()
h4=h3[(h3.zscore>-3) & (h3.zscore<3)]
print(h4.shape)
h4.head()

# %%
h4['zscore'] = ( h4.looped- h4.looped.mean() ) / h4.looped.std()
h5=h4[(h4.zscore>-3) & (h4.zscore<3)]
print(h5.shape)
h5.head()
h5=h5.rename(columns={"count":"count1"})

# %%
h5['zscore'] = ( h5.count1- h5.count1.mean() ) / h5.count1.std()
h6=h5[(h5.zscore>-3) & (h5.zscore<3)]
print(h6.shape)
h6=h6.drop('zscore',axis=1)
h6.head()

# %%
#importing libraries
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder() 
#fitting transformation
h6['mlabel']= label_encoder.fit_transform(h6['mlabel']) 

print(h6.shape)

# %%
h6

# %%
corr_matrix=h6.corr()
corr_matrix["mlabel"].sort_values(ascending=False)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
bh=h6.drop('address',axis=1)
bh=bh.drop('year',axis=1)
bh=bh.drop('day',axis=1)
bh=bh.drop('mlabel',axis=1)
scaled_data=scaler.fit_transform(bh)
scaled_data

# %%
from sklearn.decomposition import PCA
model=PCA(n_components=2)
x=model.fit_transform(scaled_data)
plt.scatter(x[:,0],x[:,1])

# %%
model.components_

# %%
import numpy as np
from sklearn.decomposition import PCA
model=PCA(n_components=6)
x=model.fit_transform(scaled_data)
model.explained_variance_ratio_

# %%
np.cumsum(model.explained_variance_ratio_)

# %%
plt.plot(np.cumsum(model.explained_variance_ratio_))

# %%
np.argmax(np.cumsum(model.explained_variance_ratio_)>0.99)

# %%
y=h6.mlabel



h6.head()

# %%
from sklearn.model_selection import train_test_split
y=h6.mlabel
X=h6.drop(columns="mlabel")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33,random_state=1)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
X_train[1]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import randint as sp_randint
from random import randrange as sp_randrange
from sklearn.model_selection import RandomizedSearchCV
# Define the hyperparameter configuration space
rf_params = {
    'n_estimators': sp_randint(10,100),
    "max_features":sp_randint(1,64),
    'max_depth': sp_randint(5,50),
    "min_samples_split":sp_randint(2,11),
    "min_samples_leaf":sp_randint(1,11),
    "criterion":['gini','entropy']
}
n_iter_search=20 #number of iterations is set to 20, you can increase this number if time permits
clf = RandomForestClassifier(random_state=0)
Random = RandomizedSearchCV(clf, param_distributions=rf_params,n_iter=n_iter_search,cv=3,scoring='accuracy')
Random.fit(X_train, y_train)
print(Random.best_params_)
print("Accuracy:"+ str(Random.best_score_))

# %%
# import the class
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression()

# fit the model with data
logreg.fit(X_train,y_train)

#prediction 
y_pred=logreg.predict(X_test)
y_pred

# %%
from sklearn.metrics import classification_report
report = classification_report(y_test, y_pred)
print(report)

# %%
from sklearn.metrics import confusion_matrix
matrix = confusion_matrix(y_test,y_pred)
print(matrix)

# %%
# import required modules
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
class_names=["ligitime","ransomware"] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

# %%
# import the metrics class
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("recall_specificity",metrics.recall_score(y_test,y_pred, pos_label=0))
print("Recall:",metrics.recall_score(y_test, y_pred))

# %%
logreg.score(X_test,y_test)

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)
y_pred

# %%
from sklearn.metrics import classification_report
report = classification_report(y_test, y_pred)
print(report)

# %%
from sklearn.metrics import confusion_matrix
matrix1 = confusion_matrix(y_test,y_pred)
print(matrix1)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("recall_specificity",metrics.recall_score(y_test,y_pred, pos_label=0))
print("Recall:",metrics.recall_score(y_test, y_pred))

# %%
# import required modules
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
class_names=["ligitime","ransomware"] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(matrix1), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %%
# import the metrics class
from sklearn import metrics
cnf_matrix1= metrics.confusion_matrix(y_test, y_pred)
cnf_matrix1

# %%
#Finding Important Features in Scikit-learn
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

# %%
import pandas as pd
feature_imp = pd.Series(clf.feature_importances_,index=h6.columns).sort_values(ascending=False)
feature_imp

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Creating a bar plot
sns.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()

# %%
# importing xgboost
from xgboost import XGBClassifier

# creating the model
model = XGBClassifier()

# fitting the model
model.fit(X_train, y_train)

# make predictions for test data
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report
report = classification_report(y_test, y_pred)
print(report)

# %%
from sklearn.metrics import confusion_matrix
matrix1 = confusion_matrix(y_test,y_pred)
print(matrix1)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("recall_specificity",metrics.recall_score(y_test,y_pred, pos_label=0))
print("Recall:",metrics.recall_score(y_test, y_pred))

# %%
# import required modules
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
class_names=["ligitime","ransomware"] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(matrix1), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

# %%
# make predictions for test data
y_pred = model.predict(X_test)

# %%
y_pred

# %%
import numpy as np
# import the metrics class
from sklearn.metrics import classification_report,accuracy_score
def performance_report (model,X_validation,y_validation):
  y_pred=model.predict(X_validation)
  

  accuracy=accuracy_score(y_validation,y_pred)
  target_names=['Negative','Positive']
  performance_report=classification_report(y_validation,y_pred,target_names,output_dict=True)
  print("\n")
  print(conf_matrix)
  print("\n")
  print(classification_report(y_validation,y_pred,target_names=target_names))
  return (y_pred,conf_matrix,accuracy,performance_report)

# %%
performance_report(logreg,X_test,y_test)
